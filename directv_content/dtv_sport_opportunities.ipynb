# %%
import pandas as pd
kwds = pd.read_csv(r"D:\Users\jackb_HDD\Development\Agency_SEO\data\Sport Team Keyword Expansion - mlb_watch_opportunites.csv")

# %%
kwds
# Out:
#                                              Keyword Currency  \
# 0                      watch the atlanta braves game      USD
# 1                      watch the boston red sox game      USD
# 2                        watch the chicago cubs game      USD
# 3                   watch the cleveland indians game      USD
# 4                    watch the colorado rockies game      USD
# ..                                               ...      ...
# 679  watch texas rangers vs detroit tigers live free      USD
# 680                           giants baseball stream      USD
# 681               watch san diego padres online free      USD
# 682                how can i watch the texas rangers      USD
# 683               stream seattle mariners games free      USD
#
#      Avg. monthly searches Competition  Competition (indexed value)  \
# 0                     50.0         Low                         11.0
# 1                     50.0         Low                          0.0
# ...

# %%
#@title Total of MLB Keyword Watch Opportunities
print("{} searches per month for MLB where to watch keywords.".format(float(kwds["Avg. monthly searches"].sum())))
# Out:
# 122150.0 searches per month for MLB where to watch keywords.

# %%
kwds["Competition"].value_counts().plot(kind="barh", title="Ranking Difficulty")

# %%
#@title exclude keywords with intent outside DirecTV's offering
neg_kwds = ["free", "reddit", "youtube", "hulu"]
intent_kwds = kwds[~kwds['Keyword'].str.contains('|'.join(neg_kwds))]
intent_kwds
# Out:
#                                    Keyword Currency  Avg. monthly searches  \
# 0            watch the atlanta braves game      USD                   50.0
# 1            watch the boston red sox game      USD                   50.0
# 2              watch the chicago cubs game      USD                   50.0
# 3         watch the cleveland indians game      USD                   50.0
# 4          watch the colorado rockies game      USD                   50.0
# ..                                     ...      ...                    ...
# 676        how to watch the nationals game      USD                   50.0
# 677                stl cardinals streaming      USD                   50.0
# 678  washington nationals game live stream      USD                   50.0
# 680                 giants baseball stream      USD                   50.0
# 682      how can i watch the texas rangers      USD                   50.0
#
# ...

# %%
#@title Summary of MLB Intent Specific Keyword Watch Opportunities
"{} searches per month for MLB where to watch keywords.".format(float(intent_kwds["Avg. monthly searches"].sum()))
# Out:
# '97450.0 searches per month for MLB where to watch keywords.'

# %%
intent_kwds["Competition"].value_counts().plot(kind="barh", title="Ranking Difficulty")
